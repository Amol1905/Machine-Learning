# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\Saifali\\Downloads\\data.csv",parse_dates=["Dates"],index_col="Dates")
data
# Out:
#                States Regions   latitude  longitude  Usage
# Dates
# 2019-02-01     Punjab      NR  31.519974  75.980003  119.9
# 2019-02-01    Haryana      NR  28.450006  77.019991  130.3
# 2019-02-01  Rajasthan      NR  26.449999  74.639981  234.1
# 2019-02-01      Delhi      NR  28.669993  77.230004   85.8
# 2019-02-01         UP      NR  27.599981  78.050006  313.9
# ...               ...     ...        ...        ...    ...
# 2020-05-12    Manipur     NER  24.799971  93.950017    2.5
# 2020-05-12  Meghalaya     NER  25.570492  91.880014    5.8
# 2020-05-12    Mizoram     NER  23.710399  92.720015    1.6
# 2020-05-12   Nagaland     NER  25.666998  94.116570    2.1
# 2020-05-12    Tripura     NER  23.835404  91.279999    3.3
#
# [16599 rows x 5 columns]

# %%
data.head(2)
# Out:
#              States Regions   latitude  longitude  Usage
# Dates
# 2019-02-01   Punjab      NR  31.519974  75.980003  119.9
# 2019-02-01  Haryana      NR  28.450006  77.019991  130.3

# %%
data.tail(2)
# Out:
#               States Regions   latitude  longitude  Usage
# Dates
# 2020-05-12  Nagaland     NER  25.666998  94.116570    2.1
# 2020-05-12   Tripura     NER  23.835404  91.279999    3.3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16599 entries, 2019-02-01 to 2020-05-12
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   States     16599 non-null  object
#  1   Regions    16599 non-null  object
#  2   latitude   16599 non-null  float64
#  3   longitude  16599 non-null  float64
#  4   Usage      16599 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 778.1+ KB

# %%
data.shape
# Out:
# (16599, 5)

# %%
data.describe()
# Out:
#            latitude     longitude         Usage
# count  16599.000000  16599.000000  16599.000000
# mean      23.178220     81.794533    103.001862
# std        6.146575      7.258429    116.044056
# min        8.900373     71.192400      0.300000
# 25%       19.820430     76.569993      6.700000
# 50%       23.835404     78.570026     64.400000
# 75%       27.333330     88.329947    173.900000
# max       33.450000     94.216667    522.100000

# %%
data.isna().sum()
# Out:
# States       0
# Regions      0
# latitude     0
# longitude    0
# Usage        0
# dtype: int64

# %%
sns.pairplot(data)

# %%
month = data.resample("M").mean()

# %%
month.head()
# Out:
#             latitude  longitude       Usage
# Dates
# 2019-01-31  23.17822  81.794533  104.701455
# 2019-02-28  23.17822  81.794533  104.794481
# 2019-03-31  23.17822  81.794533   98.533920
# 2019-04-30  23.17822  81.794533  106.853131
# 2019-05-31  23.17822  81.794533  103.320430

# %%
month.plot(subplots =  True, figsize = (15,10))
# Out:
# array([<AxesSubplot:xlabel='Dates'>, <AxesSubplot:xlabel='Dates'>,
#        <AxesSubplot:xlabel='Dates'>], dtype=object)

# %%
data.columns
# Out:
# Index(['States', 'Regions', 'latitude', 'longitude', 'Usage'], dtype='object')

# %%
plt.figure(figsize=(10,7))
plt.scatter(data=data,x='States',y='Usage',marker="o")
plt.title('Electricity States vs Usage')
# Out:
# Text(0.5, 1.0, 'Electricity States vs Usage')

# %%
sns.factorplot('Regions',data=data,kind='count')

# %%
sns.factorplot('Regions',data=data,kind='count',hue='States')
# Out:
# C:\Users\Saifali\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Saifali\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot(data=data,y="States",x="Usage")
# Out:
# C:\Users\Saifali\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(data=data,y="States",x="Usage",hue="Regions")
# Out:
# C:\Users\Saifali\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
as_fig = sns.FacetGrid(data,hue='States',aspect=3)

as_fig.map(sns.kdeplot,'Usage',shade=True)

oldest = data['Usage'].max()

as_fig.set(xlim=(0,oldest))

as_fig.add_legend()

# %%
as_fig = sns.FacetGrid(data,hue='Regions',aspect=6)

as_fig.map(sns.kdeplot,'Usage',shade=True)

oldest = data['Usage'].max()

as_fig.set(xlim=(0,oldest))

as_fig.add_legend()

# %%
data['States'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#            latitude  longitude     Usage
# latitude   1.000000   0.180809 -0.253823
# longitude  0.180809   1.000000 -0.525028
# Usage     -0.253823  -0.525028  1.000000

# %%
sns.boxplot(y = "States", x = "Usage", data = data)
# Out:
# <AxesSubplot:xlabel='Usage', ylabel='States'>

# %%
sns.histplot(y = "States",x="Usage",data = data)
# Out:
# <AxesSubplot:xlabel='Usage', ylabel='States'>

# %%
plt.figure(figsize = (25,10))
sns.heatmap(data.corr(), annot = True)
plt.show()
